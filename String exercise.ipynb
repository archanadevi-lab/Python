# %% [markdown]
# **Exercise 1. Create a string made of the first, middle, and last character**

# %%
input_string=input("Enter a string:")
first_char=input_string[0]

length_of_string=len(input_string)
mid_char=input_string[int(length_of_string/2)]

last_char=input_string[-1]
result_string=first_char+mid_char+last_char

print("The created string is:",result_string)
# Out:
# Enter a string:Marina
# The created string is: Mia

# %% [markdown]
# **Exercise 2. Create a string made of the middle three characters**

# %%
input_string="JhonDipPeta"
length_of_string=len(input_string)
res=input_string[int(length_of_string/2)-1:int(length_of_string/2)+2]
res
# Out:
# 'Dip'

# %% [markdown]
# **Exercise 3. Append new string in the middle of a given string**

# %%
s1="Ault"
s2="Kelly"
res=s1[:(len(s1)//2)]+s2+s1[(len(s1)//2):]
res
# Out:
# 'AuKellylt'

# %% [markdown]
# **Exercise 4. Create a new string made of the first, middle, and last characters of each input string**

# %%
s1 = "America"
s2 = "Japan"
res=s1[0]+s2[0]+s1[len(s1)//2]+s2[len(s2)//2]+s1[-1]+s2[-1]
res
# Out:
# 'AJrpan'

# %% [markdown]
# **Exercise 5. Reverse a given string**

# %%
s1 = "America"
print("The reversed string is:",s1[::-1])
# Out:
# The reversed string is: aciremA

# %% [markdown]
# **Exercise 6. Find the last position of a given substring**

# %%
str1 = "Emma is a data scientist who knows Python. Emma works at google."
str1.rfind("Emma")# the .rfind() method (Reverse Find) locates the most recent occurrence of a specified pattern.
# Out:
# 43

# %%
str1 = "Emma-is-a-data-scientist"
res=str1.split(sep="-")

for s in res:
  print(s)
# Out:
# Emma
# is
# a
# data
# scientist

# %% [markdown]
# **Exercise 8. Find all occurrences of a substring in a given string by ignoring the case**

# %%
str1 = "Welcome to USA. usa awesome, isn't it?"
substr="USA"

cnt=str1.lower().count(substr.lower())
print("The USA occurence in the given string:",cnt)
# Out:
# The USA occurence in the given string: 2

# %% [markdown]
# **Exercise 9. String characters balance test**

# %%
s1='yn'
s2='PyNative'
s1=list(s1)
s1
s2=list(s2)
for i in s1:
  if i not in s2:
   print("Not balanced")
   break
  else:
    continue
# Out:
# Not balanced

# %%
def string_balance_check(s1,s2):
  flag=True
  for i in s1:
    if i  in s2:
      continue
    else:
      flag=False
      break
  return flag

# %%
print("Is the given strings are balanced string:",string_balance_check('ynf','Pynative'))
# Out:
# Is the given strings are balanced string: False

# %% [markdown]
# **Exercise 10. Vowel Counter**

# %%
str1 = "Hello World"
vowels_in_string=[x for x in str1 if x in ['a','e','i','o','u']]
cnt=len(vowels_in_string)
cnt
# Out:
# 3

# %%
str1 = "Hello World"
count=0
vowels='aeiouAEIOU'
for i in str1:
  if i in vowels:
    count+=1
print(f"The number of vowels in the string are: {count}")
# Out:
# The number of vowels in the string are: 3

# %% [markdown]
# **Exercise 11. Prefix/Suffix Check**
#
#
# Practice Problem: Check if a given URL starts with “https” and ends with “.com”.

# %%
import re
str1 = "https://google.com"
pattern=r"^http.*\.com$"

if re.search(pattern,str1):
  print(True)
# Out:
# True

# %%
def is_valid_url():
 str1 = "https://google.com"
 if str1.startswith("https") and str1.endswith(".com"):
  return (True)

# %%
is_valid_url()
# Out:
# True

# %% [markdown]
# **Exercise 12. Swap Case**
#
# Write a program to toggle the case of all characters in a string (uppercase becomes lowercase and vice versa).

# %%
str1="loyalITY"
print(str1.swapcase())
# Out:
# LOYALity

# %% [markdown]
# **Exercise 13. Remove Whitespace**
#
# Remove every single space from a given string, including spaces between words.

# %%
str1 = " P y t h o n "
txt=str1.replace(" ","")
print("Cleaned string:",txt)
# Out:
# Cleaned string: Python

# %% [markdown]
# **Exercise 14. N-th Character Removal**
#
# Write a program to remove the character at index i from a string.

# %%
#Using Slicing
text='Python'
i=2
new_text=text[:i]+text[i+1:]
new_text
# Out:
# 'Pyhon'

# %% [markdown]
# **Exercise 15. String Partitioning**
#
# Use the .partition() method to split a string into three parts: the part before a separator, the separator itself, and the part after it.

# %%
str1 = "username@company.com"
res=str1.partition(".")# always returns 3 items in a tuple
res
# Out:
# ('username@company', '.', 'com')

# %%
str1 = "username.company.com"
res=str1.split(".")
res
# Out:
# ['username', 'company', 'com']

# %% [markdown]
# **Exercise 16. Extract File Extension**
#
# Given a filename as a string, extract only the file extension (e.g., .png or .pdf).

# %%
str1="test.xls"
str1.split(".")[-1]
# Out:
# 'xls'

# %% [markdown]
# **Exercise 17. Lowercase First**
#
# Write a program to arrange string characters such that all lowercase letters come first, followed by all uppercase letters.

# %%
str1='PyThOn'
first_str=[]
last_str=[]
for i in str1:
  if i.islower():
    first_str.append(i)
  else:
    last_str.append(i)
res="".join(first_str+last_str)
res
# Out:
# 'yhnPTO'

# %% [markdown]
# **18. Count all letters, digits, and special symbols from a given string**
#
# Write a program to count all letters, digits, and special symbols from a given string.

# %%
import string
str1 = "P@#yn26at^&i5ve"
chars=[]
digits=[]
symbols=[]
for i in str1:
  if i.isalpha():
    chars.append(i)
  elif i.isdigit():
    digits.append(i)
  elif (i.isalnum()==False):
    symbols.append(i)
print(f"Total number of counts of chars, digits and symbols are: chars={len(chars)} digits={len(digits)} symbols={len(symbols)}")
# Out:
# Total number of counts of chars, digits and symbols are: chars=8 digits=3 symbols=4

# %% [markdown]
# **19. Create a mixed string using alternating characters**
#
# Given two strings, s1 and s2, create a third string made of the first char of s1, then the last char of s2, Next, the second char of s1 and the second-to-last char of s2, and so on. Any left-over chars go at the end of the result.

# %%
s1='ABC'
s2='x'
s1_l=len(s1)
s2_l=len(s2)
length=s1_l if s1_l>s2_l else s2_l
result=""
s2=s2[::-1]
for i in range(length):
  if i<s1_l:
    result=result+s1[i]
  if i<s2_l:
    result=result+s2[i]
result
# Out:
# 'AxBC'

# %% [markdown]
# **20. Calculate the sum and average of the digits present in a string**
#
# Given a string, run a loop to calculate the sum and average of the digits that appear in the string. Ignore all other characters.

# %%
str1 = "PYnative29@#8496"
sum=0
cnt=0
for i in str1:
  if i.isdigit():
    sum+=int(i)
    cnt+=1
average=sum/cnt
print("sum is:",sum,"Average is:",f"{average:.2f}")
# Out:
# sum is: 38 Average is: 6.33

# %% [markdown]
# **21. Count occurrences of all characters within a string**
#
#  Count the frequency of every character in a string and store the results in a dictionary.

# %%
str1="banana"
d={}
cnt=1
for i in str1:
  if i in d:
    d[i]=d[i]+1
  if i not in d:
    d[i]=1
d
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %% [markdown]
# **22. Remove empty strings from a list of strings**
#
# Given a list of strings, remove any empty strings or None values from it.

# %%
str_list = ["Emma", "Jon", "", "Kelly", None, "Eric", ""]

new_Str=list(filter(None,str_list))
new_Str
# Out:
# ['Emma', 'Jon', 'Kelly', 'Eric']

# %% [markdown]
# **23. Remove special symbols/punctuation from a string**
#
# Write a program to remove all special symbols and punctuation from a given string.

# %%
str1 = "/*Jon is @developer & musician!!"
new_str=""
for i in str1:
  if i.isalpha() or i.isspace():
    new_str+=i

new_str
# Out:
# 'Jon is developer  musician'

# %% [markdown]
# **24. Remove all characters from a string except integers**
#
# Write a program to extract only the numeric digits from a mixed string and combine them into a single string.

# %%
str1 = "I am 25 years and 10 months old"
for i in str1:
  if i.isnumeric():
    print(i,end="")
# Out:
# 2510

# %% [markdown]
# **25. Find words with both letters and numbers**
#
# Write a program to find and print words from a string that contain both letters and numbers.

# %%
str1 = "Emma25 is Data scientist50 and AI Expert"
l=[]
for i in str1.split():
    if any(j.isdigit() for j in i) and any(j.isalpha() for j in i):
     l.append(i)
l
# Out:
# ['Emma25', 'scientist50']

# %% [markdown]
# **26. Replace each special symbol with # in the following string**
#
# Write a program to replace every special symbol (punctuation) in a string with a specific character, like #.

# %%
str1 = "/*Jon is @developer & musician!!"
for i in string.punctuation:
  str1=str1.replace(i,'#')
str1
# Out:
# '##Jon is #developer # musician##'

# %% [markdown]
# **27. Palindrome Check**
#
# Write a program to check if a string is a palindrome (reads the same forward and backward).

# %%
str1='catty'

if str1==str1[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %% [markdown]
# **28. Anagram Detector**
#
# Write a program to check if two strings are anagrams (formed by rearranging the letters of another, such as “listen” and “silent”).

# %%
def anagram(s1,s2):

  return sorted(s1.lower())==sorted(s2.lower())

s1='Pet'
s2="King"

if anagram(s1,s2):
  print("True, the given words are anagram")
else:
  print("False,the given words are not anagram")
# Out:
# False,the given words are not anagram

# %% [markdown]
# **29. Unique Character Check**
#
# Write a function to determine if a string has all unique characters. Return True if every character appears only once, otherwise return False.

# %%
str1='alphabet'
l=[]
for i in str1:
  l.append(i)
if len(set(l))==len(l):
  print(True)
else:
  print(False)
# Out:
# False

# %% [markdown]
# **30. Title Case Logic**
#
# Write a program to capitalize the first letter of every word in a sentence without using the built-in .title() method.

# %%
str1="hello world from python"
l=[]
for i in str1.split():
  l.append(i.capitalize())
" ".join(l)
# Out:
# 'Hello World From Python'

# %% [markdown]
# **31. Remove Duplicate Characters**
#
# Write a program to remove all duplicate characters from a string while keeping the remaining characters in their original order.

# %%
str1="google"
str2=''
for i in str1:
  if i not in str2:
   str2+=i
  else:
    pass
str2
# Out:
# 'gole'

# %% [markdown]
# **32. Word Reversal**
#
# Reverse the order of words in a given sentence, but keep the characters within the words in their original order.

# %%
str1="Python is fun"
l=str1.split()
res=[]
for i in l[::-1]:
  res.append(i)
res=" ".join(res)
res
# Out:
# 'fun is Python'

# %% [markdown]
# **33. Character Interleaving**
#
# Given two strings of equal length, merge them by alternating characters.

# %%
s1='ABC'
s2='XYZ'
s2=s2[::-1]
res=""
for i in range(len(s1)):
 res=res+s1[i]+s2[i]
res
# Out:
# 'AZBYCX'

# %% [markdown]
# **34. Longest Word**
#
# Write a program to find the longest word in a given sentence. If there is a tie, return the first one found.

# %%
str1="The quick brown fox jumps over the lazy dog"
d={}
for i in str1.split():
  d[i]=len(i)
max_len_str=max(d,key=d.get)
max_len_str
# Out:
# 'quick'

# %%
str1="The quick brown fox jumps over the lazy dog"
longest = max(str1.split(), key=len)

print(longest)
# Out:
# quick

# %% [markdown]
# **35. Acronym Creator**
#
# Write a program to generate an acronym from a given phrase (e.g., “Random Access Memory” becomes “RAM”).

# %%
str1 = "Random Access Memory"
acronym=[]
for i in str1.split():
  acronym.append(i[0])
acronym="".join(acronym)
acronym
# Out:
# 'RAM'

# %% [markdown]
# **36. Word Frequency**
#
# Count the occurrences of each word in a string and store the result in a dictionary.

# %%
str1 = "The cat saw a white cat"
d={}
for i in str1.split():
  if i in d:
    d[i]+=1
  else:
    d[i]=1
d
# Out:
# {'The': 1, 'cat': 2, 'saw': 1, 'a': 1, 'white': 1}

# %%
str1 = "apple banana apple cherry banana apple"
words = str1.lower().split()
word_count = {}

for word in words:
    # Get the current count (default to 0 if not found) and add 1
    word_count[word] = word_count.get(word, 0) + 1

print(word_count)
# Out:
# {'apple': 3, 'banana': 2, 'cherry': 1}

# %% [markdown]
# **37. First Non-Repeating Character**
#
# Find the first character in a string that does not repeat anywhere else.

# %%
str1="swiss"
d={}
cnt=0
for i in str1:
  if i in d:
    d[i]=d[i]+1
  if i not in d:
    d[i]=cnt+1
m=[k for k,v in d.items() if v==1]
m[0]
# Out:
# 'w'

# %%
def first_unique(s):
    counts = {}
    # First pass: count frequencies
    for char in s:
        counts[char] = counts.get(char, 0) + 1

    # Second pass: check order
    for char in s:
        if counts[char] == 1:
            return char
    return None

print("First unique in 'swiss':", first_unique("swiss"))

# %% [markdown]
# **38. String Rotation Check**
#
# Write a program to check if one string is a rotation of another (e.g., “waterbottle” is a rotation of “erbottlewat”).

# %%
s1="waterbottle"
s2="erbottlewat"

def is_rotation_check(s1,s2):

  if len(s1)!=len(s2):
    return False

  combined=s1+s1

  for i in s2:
    if i in combined:
      return True

# %%
is_rotation_check(s1,s2)
# Out:
# True
